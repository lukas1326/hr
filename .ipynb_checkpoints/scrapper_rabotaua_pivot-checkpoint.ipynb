# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import time
from selenium import webdriver
from datetime import date
import re
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore') # полезно чтобы избежать ругательства при создании нового поля таблицы(почемуто все-время ругня)

# %%
# у нас должны быть файлы со списками исключений тех ссылок, которые уже просмотрены
# function returns list of links 
def open_seen(file):
    with open(file,'r') as f:
        content=f.read()
        seen=eval(content)
    return seen

# %%
# если нужно записать файл из листа ссылок
def write_seen(file,list_links):
    with open(file, 'w') as f:
        print(list_links, file=f)

# %%
# в гугле собирает ссылки по запросу,работает только по заданному количеству листов
def google_q (query,n_pages):
    # query example:'site:rabota.ua/cv/ AND "коммерческий директор" AND "Украина" AND "FMCG"'
    # один раз устанавливаем драйвер https://sites.google.com/a/chromium.org/chromedriver/downloads

    # загружаем драйвер, открывается новое окно хрома, в этом окне делаем запрос на поиск, с каждой страницы
    # собираем нужные ссылки, закрываем драйвер

    
    # google search 
    # start driver (new chrome window)
    driver = webdriver.Chrome('C:\\ProgramData\chromedriver.exe')
    driver.get('https:www.google.com')
    time.sleep(3)

    # запрос на поиск 
    search_query = driver.find_element_by_name('q')
    search_query.send_keys(query)
    time.sleep(0.5)

    # имитация ввода запроса на поиск
    search_query.send_keys(u'\ue007')
    time.sleep(3)

    # формируем список ссылок с первых десяти страниц
    list_link=[]
    for i in range(n_pages):
        list_link.extend(ele(driver))
        next_page=driver.find_element_by_xpath("//*[contains(local-name(),'span') and contains(text(),'Уперед')]")
        next_page.click()
        time.sleep(5)
    driver.quit()
    return list_link

# %%
# вспомагательная для google_q только для ссылок с паттерном 
def ele(driver):
# получение всех ссылок rabota.ua на одной странице
    elems = driver.find_elements_by_xpath("//a[@href]")
    elems= [elem.get_attribute("href")for elem in elems]
    ln_links = [x for x in elems if re.search(r'^https://rabota.ua/cv', x)]
    return ln_links

# %%
# вспомагательная для получения супа, один раз получаем, потом из него вынимаем то, что нужно
def get_soup(link):
    response=requests.get(link)
    soup=BeautifulSoup(response.text,'html.parser')
    return soup

# %%
# вынимаем из супа только единичные значения для каждой ссылки и формируем таблицу
def soup_potato(link,soup):
    price=None
    brief=None
    age=None
    city=None
    exp=None
    edu=None
    lang=None
          
    
    
    refresh_year=soup.find('span',{'class':'muted'}).text
    update_year=re.findall('\d+',refresh_year)[1]
    
    name=soup.find('span',id='ctl00_centerZone_BriefResume1_CvView1_cvHeader_lblName').text
    
    short=soup.find('p',{'class':'rua-p-t_12'}).text.strip().split('\r\n')
    city=short[0]
    
    regex = re.compile('\d+')
    age=regex.findall(short[1])[0]
    
    try:
        regex = re.compile('\d+')
        price=regex.findall(short[2])[0]+regex.findall(short[2])[1]
    except:
        pass
    try:
        brief=soup.find('span',id='ctl00_centerZone_BriefResume1_CvView1_Skills_txtSkills').text.replace('Программное обеспечение и сервисы: ','')
    except:
        pass
    exp=soup.find('div',id='ExperienceHolder').text.replace('Опыт работы','').replace('Нет опыта работы','')
    edu=soup.find('div',id='EducationHolder').text.replace('Образование','')
    lang=soup.find('div',id='LanguagesHolder').text.replace('Владение языками','')
    scrap_date=date.today()
    field1={'name':name,'link':link,'update_year':update_year,'city':city,'age':age,'price':price,'brief':brief,'exp':exp,'edu':edu,'lang':lang,'scrap_date':scrap_date}
    df=pd.DataFrame([field1])
    
    return df

# %%
# вынимаем из супа множественные значения из каждой ссылки, например, история работы
def soup_detail(link,soup):
    gde=[]
    kogda=[]
    b1=soup.find('div',id='ExperienceHolder').find_all('b')
    m=soup.find('div',id='ExperienceHolder').find_all('em')
    for i in b1:
        gde.append(i.text.strip())
    for k in m:
        kogda.append(k.text.strip())
    
    # если слово выделено, то оно попадает в gde, там образуется шлак
    # попыталась сделать ручные исключения
    # работает плохо, но как попытка
    
    gde=[x for x in gde if "Достиж" not in x]
    gde=[x for x in gde if "Рекоменд" not in x]
    gde=[x for x in gde if "улучш" not in x]
    gde=[x for x in gde if "Результ" not in x]
    gde=[x for x in gde if "Обязанн" not in x]
    gde=[x for x in gde if "достиж" not in x]
    gde=gde[:min(len(gde),len(kogda))] # привожу два листа к одной размерности
    
    kogda=kogda[:min(len(gde),len(kogda))]# привожу два листа к одной размерности
    d = {'должность':gde,'период':kogda} # создаю словать и dataframe
    uh=pd.DataFrame(d)
    
    uh['предприятие']=uh['должность'].shift(-1)# копирую и поднимаю столбец, чтобы сделать строки
    uh['отрасль']=uh['период'].shift(-1)# копирую и поднимаю столбец, чтобы сделать строки
    
    
    
    uhh=uh.iloc[::2, :] # беру каждую вторую строку
    
    # извлекаю из строчного периода цифровой год и месяц в duration
    regex=re.compile('(\(\d+.лет|\(\d+.год)')
    uhh['год']=uhh['период'].str.extract(regex)
    uhh['год']=uhh['год'].str.extract(r'(\d+)').fillna(0)
    uhh['мес']=uhh['период'].str.extract('(\d+).мес').fillna(0)
    uhh['мес1']=uhh['мес'].astype(int)/12
    uhh['duration']=uhh['год'].astype(int)+uhh['мес1'].round(2)
    
    #формирую таблицу
    uhh['link']=link
    uhh=uhh[['link','предприятие','должность','период','отрасль','duration']].reset_index(drop=True)
    return uhh

# %%
# перемешиваем все данные по всем ссылкам в одну таблицу
def soup_stir(links):
    ddf2=pd.DataFrame(columns=['link', 'предприятие', 'должность', 'период', 'отрасль', 'duration',
       'age', 'brief', 'city', 'edu', 'exp', 'lang', 'name', 'price',
       'scrap_date', 'update_year'])
    for i in links:
        soup=get_soup(i)
        df1= soup_potato(i,soup)
        df2=soup_detail(i,soup)
        ddf1=df1.merge(df2)
        df_s1=pd.concat([ddf2,ddf1])
        ddf2=df_s1.copy()
    return df_s1

# %%
# делаем красивый консолидированный пивот
def pivot_from_soup_stir(d):
    d=d.fillna(' ')
    d1=d.reset_index()
    d2=d1.pivot_table(index=['link','name','age','brief','update_year','предприятие','должность','отрасль','index'],values='duration')
    d3=d2.sort_index(level=['link','index'])
    return d3

# %%
all_seen=open_seen('links_seen/all_seen_till_061219.txt')

# %%
len(all_seen)
# Out:
# 169

# %%
rabota_CCO=google_q('site:rabota.ua/cv/ AND "коммерческий директор" AND "Украина" AND "FMCG"',10)

# %%
len(rabota_CCO) #количество ссылок по запросу
# Out:
# 95

# %%
len([x for x in rabota_CCO if x not in all_seen]) #количество ссылок, учитывая исключения
# Out:
# 22

# %%
links1=[x for x in rabota_CCO if x not in all_seen]
len(np.unique(links1)) #проверка на уникальность
# Out:
# 22

# %%
d=soup_stir(links1[:5])

# %%
d
# Out:
#   age                                              brief    city  duration  \
# 0  46  Руководитель в области продаж с более 15 - лет...  Одесса      1.50
# 1  46  Руководитель в области продаж с более 15 - лет...  Одесса      2.00
# 2  46  Руководитель в области продаж с более 15 - лет...  Одесса      1.50
# 3  46  Руководитель в области продаж с более 15 - лет...  Одесса      2.33
# 4  46  Руководитель в области продаж с более 15 - лет...  Одесса      3.08
# 5  46  Руководитель в области продаж с более 15 - лет...  Одесса      5.17
# 6  46  Руководитель в области продаж с более 15 - лет...  Одесса      4.08
# 0  44                                               None    Киев      5.58
# 1  44                                               None    Киев      1.50
# 2  44                                               None    Киев      4.25
# 3  44                                               None    Киев      1.83
# 4  44                                               None    Киев      3.33
# 0  42                                               None    Киев     13.25
# 1  42                                               None    Киев      0.50
# 2  42                                               None    Киев      3.75
# 3  42                                               None    Киев      1.33
# 0  45  Обладаю успешным опытом построения и реализаци...    Киев      3.00
# 1  45  Обладаю успешным опытом построения и реализаци...    Киев      0.58
# 2  45  Обладаю успешным опытом построения и реализаци...    Киев      1.50
# 3  45  Обладаю успешным опытом построения и реализаци...    Киев      0.67
# 4  45  Обладаю успешным опытом построения и реализаци...    Киев      1.83
# 5  45  Обладаю успешным опытом построения и реализаци...    Киев      3.92
# 6  45  Обладаю успешным опытом построения и реализаци...    Киев      1.00
# 7  45  Обладаю успешным опытом построения и реализаци...    Киев      3.50
# 8  45  Обладаю успешным опытом построения и реализаци...    Киев      1.08
# 9  45  Обладаю успешным опытом построения и реализаци...    Киев      2.92
# 0  33                                               None    Киев      6.33
# 1  33                                               None    Киев      1.08
# 2  33                                               None    Киев      1.33
# 3  33                                               None    Киев      0.75
# 4  33                                               None    Киев      2.75
# 5  33                                               None    Киев      1.50
# 6  33                                               None    Киев      1.42
# 7  33                                               None    Киев      1.58
#
#                                                  edu  \
# 0  Одесский Государственный Политехнический Униве...
# 1  Одесский Государственный Политехнический Униве...
# 2  Одесский Государственный Политехнический Униве...
# 3  Одесский Государственный Политехнический Униве...
# 4  Одесский Государственный Политехнический Униве...
# 5  Одесский Государственный Политехнический Униве...
# 6  Одесский Государственный Политехнический Униве...
# 0  Переяслав-Хмельницкий государственный педагоги...
# 1  Переяслав-Хмельницкий государственный педагоги...
# 2  Переяслав-Хмельницкий государственный педагоги...
# 3  Переяслав-Хмельницкий государственный педагоги...
# 4  Переяслав-Хмельницкий государственный педагоги...
# 0  Полтавский национальный технический университе...
# 1  Полтавский национальный технический университе...
# 2  Полтавский национальный технический университе...
# 3  Полтавский национальный технический университе...
# 0  Международный институт рыночных отношений и пр...
# 1  Международный институт рыночных отношений и пр...
# 2  Международный институт рыночных отношений и пр...
# 3  Международный институт рыночных отношений и пр...
# 4  Международный институт рыночных отношений и пр...
# 5  Международный институт рыночных отношений и пр...
# 6  Международный институт рыночных отношений и пр...
# 7  Международный институт рыночных отношений и пр...
# 8  Международный институт рыночных отношений и пр...
# 9  Международный институт рыночных отношений и пр...
# 0  Житомирский государственный университет им. И....
# 1  Житомирский государственный университет им. И....
# 2  Житомирский государственный университет им. И....
# 3  Житомирский государственный университет им. И....
# 4  Житомирский государственный университет им. И....
# 5  Житомирский государственный университет им. И....
# 6  Житомирский государственный университет им. И....
# 7  Житомирский государственный университет им. И....
#
#                                                  exp  \
# 0  \r\nРуководитель отдела развитияфев 2017 - июл...
# 1  \r\nРуководитель отдела развитияфев 2017 - июл...
# 2  \r\nРуководитель отдела развитияфев 2017 - июл...
# 3  \r\nРуководитель отдела развитияфев 2017 - июл...
# 4  \r\nРуководитель отдела развитияфев 2017 - июл...
# 5  \r\nРуководитель отдела развитияфев 2017 - июл...
# 6  \r\nРуководитель отдела развитияфев 2017 - июл...
# 0  \r\nРегиональный менеджер FMCGиюн 2014 - насто...
# 1  \r\nРегиональный менеджер FMCGиюн 2014 - насто...
# 2  \r\nРегиональный менеджер FMCGиюн 2014 - насто...
# 3  \r\nРегиональный менеджер FMCGиюн 2014 - насто...
# 4  \r\nРегиональный менеджер FMCGиюн 2014 - насто...
# 0  \r\nРегиональный менеджер FMCGокт 2006 - насто...
# 1  \r\nРегиональный менеджер FMCGокт 2006 - насто...
# 2  \r\nРегиональный менеджер FMCGокт 2006 - насто...
# 3  \r\nРегиональный менеджер FMCGокт 2006 - насто...
# 0  \r\nКонультант по развитию бизнеса (Business  ...
# 1  \r\nКонультант по развитию бизнеса (Business  ...
# 2  \r\nКонультант по развитию бизнеса (Business  ...
# 3  \r\nКонультант по развитию бизнеса (Business  ...
# 4  \r\nКонультант по развитию бизнеса (Business  ...
# 5  \r\nКонультант по развитию бизнеса (Business  ...
# 6  \r\nКонультант по развитию бизнеса (Business  ...
# 7  \r\nКонультант по развитию бизнеса (Business  ...
# 8  \r\nКонультант по развитию бизнеса (Business  ...
# 9  \r\nКонультант по развитию бизнеса (Business  ...
# 0  \r\nКоммерческий директорсен 2013 - настоящее ...
# 1  \r\nКоммерческий директорсен 2013 - настоящее ...
# 2  \r\nКоммерческий директорсен 2013 - настоящее ...
# 3  \r\nКоммерческий директорсен 2013 - настоящее ...
# 4  \r\nКоммерческий директорсен 2013 - настоящее ...
# 5  \r\nКоммерческий директорсен 2013 - настоящее ...
# 6  \r\nКоммерческий директорсен 2013 - настоящее ...
# 7  \r\nКоммерческий директорсен 2013 - настоящее ...
#
#                                                 lang  \
# 0  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 1  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 2  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 3  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 4  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 5  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 6  Английский- базовый\r\n\t\t\t\r\n\t\tУкраински...
# 0  Русский- родной\r\n\t\t\t\r\n\t\tУкраинский- р...
# 1  Русский- родной\r\n\t\t\t\r\n\t\tУкраинский- р...
# 2  Русский- родной\r\n\t\t\t\r\n\t\tУкраинский- р...
# 3  Русский- родной\r\n\t\t\t\r\n\t\tУкраинский- р...
# 4  Русский- родной\r\n\t\t\t\r\n\t\tУкраинский- р...
# 0
# 1
# 2
# 3
# 0  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 1  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 2  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 3  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 4  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 5  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 6  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 7  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 8  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 9  Английский- средний\r\n\t\t\t\r\n\t\tРусский- ...
# 0  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 1  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 2  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 3  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 4  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 5  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 6  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
# 7  Английский- продвинутый\r\n\t\t\t\r\n\t\tРусск...
#
#                            link                  name  price  scrap_date  \
# 0  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 1  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 2  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 3  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 4  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 5  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 6  https://rabota.ua/cv/9778845       Олег Николаевич   None  2019-12-17
# 0  https://rabota.ua/cv/4760938             Александр   None  2019-12-17
# 1  https://rabota.ua/cv/4760938             Александр   None  2019-12-17
# 2  https://rabota.ua/cv/4760938             Александр   None  2019-12-17
# 3  https://rabota.ua/cv/4760938             Александр   None  2019-12-17
# 4  https://rabota.ua/cv/4760938             Александр   None  2019-12-17
# 0  https://rabota.ua/cv/8275403                Роберт   None  2019-12-17
# 1  https://rabota.ua/cv/8275403                Роберт   None  2019-12-17
# 2  https://rabota.ua/cv/8275403                Роберт   None  2019-12-17
# 3  https://rabota.ua/cv/8275403                Роберт   None  2019-12-17
# 0  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 1  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 2  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 3  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 4  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 5  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 6  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 7  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 8  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 9  https://rabota.ua/cv/5757043  Виталий Владимирович   None  2019-12-17
# 0  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 1  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 2  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 3  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 4  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 5  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 6  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
# 7  https://rabota.ua/cv/5150430       Юрий Викторович  20000  2019-12-17
#
#   update_year                                          должность  \
# 0        2019                       Руководитель отдела развития
# 1        2019                              Региональный менеджер
# 2        2019  Региональный менеджер по работе с ключевыми кл...
# 3        2019  Региональный Менеджер по работе с ключевыми кл...
# 4        2019  Региональный  менеджер по работе с ключевыми к...
# 5        2019  Региональный менеджер по работе с ключевыми кл...
# 6        2019                                        Супервайзер
# 0        2019                         Региональный менеджер FMCG
# 1        2019                              Коммерческий директор
# 2        2019                            руководитель отдела ВЭД
# 3        2019                                       Директор ВЭД
# 4        2019              Менеджер по работе с торговыми сетями
# 0        2017                         Региональный менеджер FMCG
# 1        2017                         Региональный представитель
# 2        2017                                        Супервайзер
# 3        2017                               Менеджер по закупкам
# 0        2019  Конультант по развитию бизнеса (Business  deve...
# 1        2019                                Управляющий партнер
# 2        2019                                Управляющий партнер
# 3        2019                        Директор по развитию продаж
# 4        2019                                        Собственник
# 5        2019                                             BIGSUN
# 6        2019                                      MetLife Alico
# 7        2019  Директор по вопросам регионального развития (BDM)
# 8        2019             Коммерческий Директор (Член правления)
# 9        2019  ТАС, Страховая компания, собственная агентская...
# 0        2016                              Коммерческий директор
# 1        2016    Национальный менеджер по работе с VIP клиентами
# 2        2016                          Руководитель департамента
# 3        2016                             Интерснек Украина, ООО
# 4        2016  условия сотрудничества; листинг/ротация продук...
# 5        2016  -Проведение презентаций (сетям, дистрибьюторам...
# 6        2016                            -Планирование Forecast;
# 7        2016      -Работа с торговой командой, дистрибьюторами;
#
#                                              отрасль  \
# 0                    АПК (Агропромышленный комплекс)
# 1                                               FMCG
# 2            более 500 сотрудников\r\n\t\t\t\t\tFMCG
# 3                                               FMCG
# 4                                               FMCG
# 5            более 500 сотрудников\r\n\t\t\t\t\tFMCG
# 6  более 500 сотрудников\r\n\t\t\t\t\tТорговля оп...
# 0        от 100 до 250 сотрудников\r\n\t\t\t\t\tFMCG
# 1  от 20 до 50 сотрудников\r\n\t\t\t\t\tТорговля ...
# 2                                               FMCG
# 3          от 20 до 50 сотрудников\r\n\t\t\t\t\tFMCG
# 4  от 50 до 100 сотрудников\r\n\t\t\t\t\tТорговля...
# 0                                               FMCG
# 1                                               FMCG
# 2        от 100 до 250 сотрудников\r\n\t\t\t\t\tFMCG
# 3      от 100 до 250 сотрудников\r\n\t\t\t\t\tДругое
# 0                                 Консалтинг / Аудит
# 1    Торговля оптовая / Дистрибуция / Импорт-экспорт
# 2  от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговл...
# 3     более 500 сотрудников\r\n\t\t\t\t\tСтрахование
# 4     более 500 сотрудников\r\n\t\t\t\t\tСтрахование
# 5  от 100 до 250 сотрудников\r\n\t\t\t\t\tСтрахов...
# 6  от 50 до 100 сотрудников\r\n\t\t\t\t\tФармацев...
# 7                                               FMCG
# 8  от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговл...
# 9        от 250 до 500 сотрудников\r\n\t\t\t\t\tFMCG
# 0                                               FMCG
# 1                                               FMCG
# 2          от 20 до 50 сотрудников\r\n\t\t\t\t\tFMCG
# 3  от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговл...
# 4            более 500 сотрудников\r\n\t\t\t\t\tFMCG
# 5                                               FMCG
# 6         от 50 до 100 сотрудников\r\n\t\t\t\t\tFMCG
# 7  от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговл...
#
#                                       период  \
# 0          фев 2017 - июл 2018 (1 год 6 мес)
# 1               фев 2015 - янв 2017 (2 года)
# 2          июл 2013 - дек 2014 (1 год 6 мес)
# 3         мар 2011 - июн 2013 (2 года 4 мес)
# 4         янв 2008 - янв 2011 (3 года 1 мес)
# 5          авг 2002 - сен 2007 (5 лет 2 мес)
# 6         янв 1998 - янв 2002 (4 года 1 мес)
# 0   июн 2014 - настоящее время (5 лет 7 мес)
# 1          янв 2013 - июн 2014 (1 год 6 мес)
# 2         окт 2008 - дек 2012 (4 года 3 мес)
# 3         ноя 2006 - авг 2008 (1 год 10 мес)
# 4         июн 2003 - сен 2006 (3 года 4 мес)
# 0  окт 2006 - настоящее время (13 лет 3 мес)
# 1                май 2006 - окт 2006 (6 мес)
# 2         сен 2002 - май 2006 (3 года 9 мес)
# 3          май 2001 - авг 2002 (1 год 4 мес)
# 0        янв 2017 - настоящее время (3 года)
# 1                июн 2016 - дек 2016 (7 мес)
# 2          дек 2014 - май 2016 (1 год 6 мес)
# 3                авг 2013 - мар 2014 (8 мес)
# 4         авг 2011 - май 2013 (1 год 10 мес)
# 5        ноя 2007 - сен 2011 (3 года 11 мес)
# 6                ноя 2006 - окт 2007 (1 год)
# 7         янв 2003 - июн 2006 (3 года 6 мес)
# 8          янв 2002 - янв 2003 (1 год 1 мес)
# 9        мар 1999 - янв 2002 (2 года 11 мес)
# 0   сен 2013 - настоящее время (6 лет 4 мес)
# 1          сен 2012 - сен 2013 (1 год 1 мес)
# 2          июн 2011 - сен 2012 (1 год 4 мес)
# 3                окт 2010 - июн 2011 (9 мес)
# 4         дек 2007 - авг 2010 (2 года 9 мес)
# 5          июл 2006 - дек 2007 (1 год 6 мес)
# 6          мар 2005 - июл 2006 (1 год 5 мес)
# 7          сен 2003 - мар 2005 (1 год 7 мес)
#
#                                          предприятие
# 0                ООО Велес Агро Брокер (Агроэкспорт)
# 1                    ООО «Ритейл Профешинлз Украина»
# 2                       Кока-Кола Беверіджиз Україна
# 3        ПАО Мироновский Хлебопродукт (ТМ Наша Ряба)
# 4                                          ЗАО Чумак
# 5         Монделіс Україна, ПАТ / Крафт Фудз Україна
# 6                                    АЛМИ-Трейд, ООО
# 0                            С-транс, ООО / Inmilkco
# 1                                           Геотранс
# 2                               ДП Милкиленд-Украина
# 3                                       менеджер ВЭД
# 4                                 Торговый дом Любас
# 0                                          Bonduelle
# 1                                        Best seller
# 2                                    Wrigley Ukraine
# 3                                     Золотой Восток
# 0                                   Skylark Servises
# 1                                Управляющий партнер
# 2                                Управляющий партнер
# 3                                           ЮД"Sofi"
# 4                        Коммерческий Директор (CSO)
# 5  Директор по развитию продаж в Филиальной сети ...
# 6                            Директор Агентской сети
# 7                            CK "Aegon Life Ukraine"
# 8  Директор по развитию агентского канала продаж ...
# 9                                  Директор Агенства
# 0                      ТОВ "Компания Редимилс Трейд"
# 1                              ТОВ «Петрус Кондитер»
# 2  Национальный менеджер по работе с ключевыми кл...
# 3         -Проведение переговоров(годовые, текущие):
# 4             - Контроль выполнения договоренностей;
# 5  -Прогнозирование, контроль эффективного исполь...
# 6  -Планирование и контроль выполнения маркетинго...
# 7                     -Проведение аудита территории;

# %%
pivot_from_soup_stir(d)
# Out:
#                                                                                                                                                                                                                                                                                      duration
# link                         name                 age brief                                              update_year предприятие                                        должность                                          отрасль                                            index
# https://rabota.ua/cv/4760938 Александр            44                                                     2019        С-транс, ООО / Inmilkco                            Региональный менеджер FMCG                         от 100 до 250 сотрудников\r\n\t\t\t\t\tFMCG        0          5.58
#                                                                                                                      Геотранс                                           Коммерческий директор                              от 20 до 50 сотрудников\r\n\t\t\t\t\tТорговля о... 1          1.50
#                                                                                                                      ДП Милкиленд-Украина                               руководитель отдела ВЭД                            FMCG                                               2          4.25
#                                                                                                                      менеджер ВЭД                                       Директор ВЭД                                       от 20 до 50 сотрудников\r\n\t\t\t\t\tFMCG          3          1.83
#                                                                                                                      Торговый дом Любас                                 Менеджер по работе с торговыми сетями              от 50 до 100 сотрудников\r\n\t\t\t\t\tТорговля ... 4          3.33
# https://rabota.ua/cv/5150430 Юрий Викторович      33                                                     2016        ТОВ "Компания Редимилс Трейд"                      Коммерческий директор                              FMCG                                               0          6.33
#                                                                                                                      ТОВ «Петрус Кондитер»                              Национальный менеджер по работе с VIP клиентами    FMCG                                               1          1.08
#                                                                                                                      Национальный менеджер по работе с ключевыми кли... Руководитель департамента                          от 20 до 50 сотрудников\r\n\t\t\t\t\tFMCG          2          1.33
#                                                                                                                      -Проведение переговоров(годовые, текущие):         Интерснек Украина, ООО                             от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговля... 3          0.75
#                                                                                                                      - Контроль выполнения договоренностей;             условия сотрудничества; листинг/ротация продукц... более 500 сотрудников\r\n\t\t\t\t\tFMCG            4          2.75
#                                                                                                                      -Прогнозирование, контроль эффективного использ... -Проведение презентаций (сетям, дистрибьюторам,... FMCG                                               5          1.50
#                                                                                                                      -Планирование и контроль выполнения маркетингов... -Планирование Forecast;                            от 50 до 100 сотрудников\r\n\t\t\t\t\tFMCG         6          1.42
#                                                                                                                      -Проведение аудита территории;                     -Работа с торговой командой, дистрибьюторами;      от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговля... 7          1.58
# https://rabota.ua/cv/5757043 Виталий Владимирович 45  Обладаю успешным опытом построения и реализации... 2019        Skylark Servises                                   Конультант по развитию бизнеса (Business  devel... Консалтинг / Аудит                                 0          3.00
#                                                                                                                      Управляющий партнер                                Управляющий партнер                                Торговля оптовая / Дистрибуция / Импорт-экспорт    1          0.58
#                                                                                                                                                                                                                            от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговля... 2          1.50
#                                                                                                                      ЮД"Sofi"                                           Директор по развитию продаж                        более 500 сотрудников\r\n\t\t\t\t\tСтрахование     3          0.67
#                                                                                                                      Коммерческий Директор (CSO)                        Собственник                                        более 500 сотрудников\r\n\t\t\t\t\tСтрахование     4          1.83
#                                                                                                                      Директор по развитию продаж в Филиальной сети (... BIGSUN                                             от 100 до 250 сотрудников\r\n\t\t\t\t\tСтрахование 5          3.92
#                                                                                                                      Директор Агентской сети                            MetLife Alico                                      от 50 до 100 сотрудников\r\n\t\t\t\t\tФармацевтика 6          1.00
#                                                                                                                      CK "Aegon Life Ukraine"                            Директор по вопросам регионального развития (BDM)  FMCG                                               7          3.50
#                                                                                                                      Директор по развитию агентского канала продаж /... Коммерческий Директор (Член правления)             от 100 до 250 сотрудников\r\n\t\t\t\t\tТорговля... 8          1.08
#                                                                                                                      Директор Агенства                                  ТАС, Страховая компания, собственная агентская ... от 250 до 500 сотрудников\r\n\t\t\t\t\tFMCG        9          2.92
# https://rabota.ua/cv/8275403 Роберт               42                                                     2017        Bonduelle                                          Региональный менеджер FMCG                         FMCG                                               0         13.25
#                                                                                                                      Best seller                                        Региональный представитель                         FMCG                                               1          0.50
#                                                                                                                      Wrigley Ukraine                                    Супервайзер                                        от 100 до 250 сотрудников\r\n\t\t\t\t\tFMCG        2          3.75
#                                                                                                                      Золотой Восток                                     Менеджер по закупкам                               от 100 до 250 сотрудников\r\n\t\t\t\t\tДругое      3          1.33
# https://rabota.ua/cv/9778845 Олег Николаевич      46  Руководитель в области продаж с более 15 - летн... 2019        ООО Велес Агро Брокер (Агроэкспорт)                Руководитель отдела развития                       АПК (Агропромышленный комплекс)                    0          1.50
#                                                                                                                      ООО «Ритейл Профешинлз Украина»                    Региональный менеджер                              FMCG                                               1          2.00
#                                                                                                                      Кока-Кола Беверіджиз Україна                       Региональный менеджер по работе с ключевыми кли... более 500 сотрудников\r\n\t\t\t\t\tFMCG            2          1.50
#                                                                                                                      ПАО Мироновский Хлебопродукт (ТМ Наша Ряба)        Региональный Менеджер по работе с ключевыми кли... FMCG                                               3          2.33
#                                                                                                                      ЗАО Чумак                                          Региональный  менеджер по работе с ключевыми кл... FMCG                                               4          3.08
#                                                                                                                      Монделіс Україна, ПАТ / Крафт Фудз Україна         Региональный менеджер по работе с ключевыми кли... более 500 сотрудников\r\n\t\t\t\t\tFMCG            5          5.17
#                                                                                                                      АЛМИ-Трейд, ООО                                    Супервайзер                                        более 500 сотрудников\r\n\t\t\t\t\tТорговля опт... 6          4.08
